# %%
import pandas as pd
import sqlite3
import warnings
import pyodbc
import numpy as np

warnings.simplefilter('ignore')
print(pyodbc.drivers())
# Out:
# ['ODBC Driver 17 for SQL Server']

# %% [markdown]
# <h3> connecties leggen/inlezen van sqlite bestanden en csv files inlezen

# %%
connSales = sqlite3.connect('data/raw/go_sales_train2.sqlite')
connTrain = sqlite3.connect('data/raw/go_staff_train.sqlite')
connCRM = sqlite3.connect('data/raw/go_crm_train.sqlite')

# Pad naar de CSV-bestanden
inventory_levels_path = 'data/raw/inventory_levels_train.csv'
product_forecast_path = 'data/raw/product_forecast_train.csv' 

# Lees de CSV-bestanden in
inventory_levels_df = pd.read_csv(inventory_levels_path, index_col=0)
product_forecast_df = pd.read_csv(product_forecast_path)

# Bekijk de eerste paar rijen van de DataFrames
print(inventory_levels_df.head())
print(product_forecast_df.head())

for conn in [connSales, connTrain, connCRM]:
    print("SQLite3 Connection: ",conn)
# Out:
#    INVENTORY_YEAR  INVENTORY_MONTH  PRODUCT_NUMBER  INVENTORY_COUNT
# 0            2023                4              48             1932
# 1            2023                4              49             1400
# 2            2023                4              50            21705
# 3            2023                4              51             9710
# 4            2023                4              52             5616
#    PRODUCT_NUMBER  YEAR  MONTH  EXPECTED_VOLUME
# 0              45  2023     12               90
# 1              46  2023     12               84
# 2              47  2023     12              468
# 3              48  2023     12               91
# 4              49  2023     12               35
# SQLite3 Connection:  <sqlite3.Connection object at 0x113706e30>
# SQLite3 Connection:  <sqlite3.Connection object at 0x113706d40>
# SQLite3 Connection:  <sqlite3.Connection object at 0x1137058a0>

# %%
# Functie om alle tabellen uit een SQLite-database in te lezen
def load_sqlite_tables_to_dfs(conn):
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    dfs = {}
    for table_name in tables:
        table_name = table_name[0]
        dfs[table_name] = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    return dfs


# Lees alle tabellen van alle SQLite-databases in
all_dfs = {
    'go_sales_train2.sqlite': load_sqlite_tables_to_dfs(connSales),
    'go_staff_train.sqlite': load_sqlite_tables_to_dfs(connTrain),
    'go_crm_train.sqlite': load_sqlite_tables_to_dfs(connCRM),
    'inventory_levels_train.csv': {'inventory_levels': inventory_levels_df},
    'product_forecast_train.csv': {'product_forecast': product_forecast_df}
}


# Voorbeeld: Bekijk de eerste paar rijen van een specifieke tabel in een specifieke database
db_name = 'go_sales_train2.sqlite'
table_name = 'sales_branch'  # Vervang dit door de naam van een tabel in de database
if db_name in all_dfs and table_name in all_dfs[db_name]:
    print(all_dfs[db_name][table_name].head())
else:
    print(f"Tabel {table_name} niet gevonden in database {db_name}")




 # Sluit de verbindingen wanneer je klaar bent
for conn in [connSales, connTrain, connCRM]:
    print("SQLite3 Connection: ", conn)
    conn.close()
# Out:
#    SALES_BRANCH_CODE                       ADDRESS1       ADDRESS2       CITY  \
# 0                  6  75, rue du Faubourg St-Honoré           None      Paris
# 1                  7                Piazza Duomo, 1           None     Milano
# 2                  9            Singelgravenplein 4  4e verdieping  Amsterdam
# 3                 13                 Schwabentor 35           None    Hamburg
# 4                 14               Leopoldstraße 36           None    München
#
#           REGION POSTAL_ZONE  COUNTRY_CODE
# 0           None     F-75008             1
# 1           None     I-20121             6
# 2  Noord-Holland     1233 BW             7
# 3           None     D-22529             2
# 4           None     D-81241             2
# SQLite3 Connection:  <sqlite3.Connection object at 0x113706e30>
# SQLite3 Connection:  <sqlite3.Connection object at 0x113706d40>
# SQLite3 Connection:  <sqlite3.Connection object at 0x1137058a0>

# %% [markdown]
# <h1>Verbinden met sql server

# %%
# Stel je verbindingsgegevens in
server = '127.0.0.1'        
port = '1433'               
database = 'GreatOutdoors_SDM'         
username = 'SA'             
password = 'iDTyjZx7dRL4'  

# Maak de connection string
connection_string = (
    f"DRIVER={{ODBC Driver 17 for SQL Server}};"
    f"SERVER={server},{port};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    "TrustServerCertificate=yes;"  # Voorkomt SSL-warnings bij self-signed
    "Timeout=30;"
)

'''
try:
    # Verbind met de database
    conn = pyodbc.connect(connection_string)
    cursor = conn.cursor()

    # Test: maak een query (bijv. checken of de verbinding werkt)
    cursor.execute("SELECT @@VERSION;")
    row = cursor.fetchone()
    print("SQL Server versie:", row[0])

    # Sluit de verbindingen wanneer je klaar bent
    cursor.close()
    conn.close()
except pyodbc.Error as ex:
    sqlstate = ex.args[1]
    print(f"OperationalError: {sqlstate}")
    
    '''
# Out:
# '\ntry:\n    # Verbind met de database\n    conn = pyodbc.connect(connection_string)\n    cursor = conn.cursor()\n\n    # Test: maak een query (bijv. checken of de verbinding werkt)\n    cursor.execute("SELECT @@VERSION;")\n    row = cursor.fetchone()\n    print("SQL Server versie:", row[0])\n\n    # Sluit de verbindingen wanneer je klaar bent\n    cursor.close()\n    conn.close()\nexcept pyodbc.Error as ex:\n    sqlstate = ex.args[1]\n    print(f"OperationalError: {sqlstate}")\n    \n    '

# %% [markdown]
# <h4> dict testen

# %%
# Print de eerste paar rijen van elke DataFrame in de dictionary
for db_name, tables in all_dfs.items():
    print(f"\nDatabase/CSV: {db_name}")
    for table_name, df in tables.items():
        print(f"\nTable: {table_name}")
        print(df.head())



# merge sales branch in go_sales_train2.sqlite en go_staff_train.sqlite

#merge sales staff in go_sales_train2.sqlite en go_staff_train.sqlite

#de twee “country”-definities zijn samengevoegd tot één tabel "Country" met zowel de verkoop- als CRM-attributen.
#De tabel “crm_country” en “crm_retailer_site” zijn geheel verwijderd.
# Out:
# Database/CSV: go_sales_train2.sqlite
#
# Table: country
#    COUNTRY_CODE        COUNTRY LANGUAGE CURRENCY_NAME
# 0             1         France       EN        francs
# 1             2        Germany       EN         marks
# 2             3  United States       EN       dollars
# 3             4         Canada       EN       dollars
# 4             5        Austria       EN    schillings
#
# Table: order_details
#    ORDER_DETAIL_CODE  ORDER_NUMBER  PRODUCT_NUMBER  QUANTITY  UNIT_COST  \
# 0              47737          1638               1        84       4.38
# 1              47738          1159               1       126       4.38
# 2              47739          1171               1       122       4.38
# 3              47740          1154               1       122       4.38
# 4              47741          1205               1       272       4.38
#
#    UNIT_PRICE  UNIT_SALE_PRICE
# 0        6.59             6.59
# 1        6.59             6.59
# 2        6.59             6.03
# 3        6.59             6.59
# 4        6.59             5.26
#
# Table: order_header
#    ORDER_NUMBER RETAILER_NAME  RETAILER_SITE_CODE  RETAILER_CONTACT_CODE  \
# 0          1153  Ultra Sports                   4                      6
# 1          1154  Ultra Sports                   4                      6
# 2          1155  Ultra Sports                   5                     65
# 3          1156  Ultra Sports                   5                     65
# 4          1157  Ultra Sports                   6                     66
#
#    SALES_STAFF_CODE  SALES_BRANCH_CODE  ORDER_DATE  ORDER_METHOD_CODE
# 0                50                 18  2022-04-14                  7
# 1                50                 18  2022-10-01                  4
# 2                49                 18  2022-04-21                  7
# 3                49                 18  2022-09-09                  5
# 4                50                 18  2022-04-10                  2
#
# Table: order_method
#    ORDER_METHOD_CODE ORDER_METHOD_EN
# 0                  1             Fax
# 1                  2       Telephone
# 2                  3            Mail
# 3                  4          E-mail
# 4                  5             Web
#
# Table: product
#    PRODUCT_NUMBER INTRODUCTION_DATE  PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0               1        1995-02-15                  1             4.00
# 1               2        1995-02-15                  1             9.22
# 2               3        1995-02-15                  1            15.93
# 3               4        1995-02-15                  1             5.00
# 4               5        1995-02-15                  1            34.97
#
#    MARGIN  PRODUCT_IMAGE LANGUAGE           PRODUCT_NAME  \
# 0    0.33  P01CE1CG1.jpg       EN    TrailChef Water Bag
# 1    0.23  P02CE1CG1.jpg       EN      TrailChef Canteen
# 2    0.28  P03CE1CG1.jpg       EN  TrailChef Kitchen Kit
# 3    0.28  P04CE1CG1.jpg       EN          TrailChef Cup
# 4    0.30  P05CE1CG1.jpg       EN     TrailChef Cook Set
#
#                                          DESCRIPTION
# 0  Lightweight, collapsible bag to carry liquids ...
# 1  Aluminum canteen. Rugged fleece-lined cover wi...
# 2  Zippered nylon pouch contains cutlery for two,...
# 3            Tin cup. Holds 0.4 liters. Weight: 60 g
# 4  All you will ever need on the trail.  Pot grip...
#
# Table: product_line
#    PRODUCT_LINE_CODE           PRODUCT_LINE_EN
# 0                  1         Camping Equipment
# 1                  2  Mountaineering Equipment
# 2                  3      Personal Accessories
# 3                  4        Outdoor Protection
# 4                  5            Golf Equipment
#
# Table: product_type
#    PRODUCT_TYPE_CODE  PRODUCT_LINE_CODE PRODUCT_TYPE_EN
# 0                  1                  1    Cooking Gear
# 1                  2                  1           Tents
# 2                  3                  1   Sleeping Bags
# 3                  4                  1           Packs
# 4                  5                  1        Lanterns
#
# Table: retailer_site
#    RETAILER_SITE_CODE  RETAILER_CODE            ADDRESS1 ADDRESS2  \
# 0                   1             89  1117 Franklin Blvd     None
# 1                   2             89     45, rue Atwater     None
# 2                   3             89    328 Hodgson Road     None
# 3                   4             90      2425, rue Peel     None
# 4                   5             90       34 8th Avenue     None
#
#           CITY         REGION POSTAL_ZONE  COUNTRY_CODE  ACTIVE_INDICATOR
# 0     Winnipeg       Manitoba     R2C 0M5             4                 1
# 1     Montréal         Québec     H2T 9K8             4                 1
# 2  Fredericton  New Brunswick     E3B 2H2             4                 1
# 3     Montréal         Québec     H4G 3T4             4                 1
# 4      Sudbury        Ontario     M5V 1G5             4                 1
#
# Table: return_reason
#    RETURN_REASON_CODE   RETURN_DESCRIPTION_EN
# 0                   1       Defective product
# 1                   2      Incomplete product
# 2                   3   Wrong product ordered
# 3                   4   Wrong product shipped
# 4                   5  Unsatisfactory product
#
# Table: returned_item
#    RETURN_CODE          RETURN_DATE  ORDER_DETAIL_CODE  RETURN_REASON_CODE  \
# 0         1491  Aug  1 2023  4:10AM              84858                   5
# 1         1492  Dec  6 2022  6:46PM              84440                   2
# 2         1493  Jun 24 2023  9:23AM              84867                   4
# 3         1494  Jul 21 2023 12:00AM              84873                   3
# 4         1496  Oct  7 2022  5:13AM              84488                   1
#
#    RETURN_QUANTITY
# 0                8
# 1                2
# 2               22
# 3               20
# 4                2
#
# Table: sales_branch
#    SALES_BRANCH_CODE                       ADDRESS1       ADDRESS2       CITY  \
# 0                  6  75, rue du Faubourg St-Honoré           None      Paris
# 1                  7                Piazza Duomo, 1           None     Milano
# 2                  9            Singelgravenplein 4  4e verdieping  Amsterdam
# 3                 13                 Schwabentor 35           None    Hamburg
# 4                 14               Leopoldstraße 36           None    München
#
#           REGION POSTAL_ZONE  COUNTRY_CODE
# 0           None     F-75008             1
# 1           None     I-20121             6
# 2  Noord-Holland     1233 BW             7
# 3           None     D-22529             2
# 4           None     D-81241             2
#
# Table: sales_staff
#    SALES_STAFF_CODE FIRST_NAME  LAST_NAME                   POSITION_EN  \
# 0                 4      Denis       Pagé                Branch Manager
# 1                 5  Élizabeth     Michel  Level 3 Sales Representative
# 2                 6      Émile   Clermont  Level 1 Sales Representative
# 3                 7    Étienne     Jauvin  Level 2 Sales Representative
# 4                12    Elsbeth  Wiesinger  Level 2 Sales Representative
#
#           WORK_PHONE  EXTENSION                FAX                   EMAIL  \
# 0  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60       DPage@grtd123.com
# 1  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60     EMichel@grtd123.com
# 2  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60   EClermont@grtd123.com
# 3  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60     EJauvin@grtd123.com
# 4  +(49) 40 663 1990     1818.0  +(49) 40 663 4571  EWiesinger@grtd123.com
#
#    DATE_HIRED  SALES_BRANCH_CODE
# 0  1996-11-03                  6
# 1  1995-06-08                  6
# 2  1998-04-07                  6
# 3  1997-08-16                  6
# 4  1997-02-27                 13
#
# Database/CSV: go_staff_train.sqlite
#
# Table: course
#    COURSE_CODE COURSE_DESCRIPTION
# 0            1     GO Orientation
# 1            2   GO Communication
# 2            3         GO Sales 1
# 3            4         GO Sales 2
# 4            5     GO Marketing 1
#
# Table: sales_branch
#    SALES_BRANCH_CODE                       ADDRESS1       ADDRESS2       CITY  \
# 0                  6  75, rue du Faubourg St-Honoré           None      Paris
# 1                  7                Piazza Duomo, 1           None     Milano
# 2                  9            Singelgravenplein 4  4e verdieping  Amsterdam
# 3                 13                 Schwabentor 35           None    Hamburg
# 4                 14               Leopoldstraße 36           None    München
#
#           REGION POSTAL_ZONE  COUNTRY_CODE
# 0           None     F-75008             1
# 1           None     I-20121             6
# 2  Noord-Holland     1233 BW             7
# 3           None     D-22529             2
# 4           None     D-81241             2
#
# Table: sales_staff
#    SALES_STAFF_CODE FIRST_NAME  LAST_NAME                   POSITION_EN  \
# 0                 4      Denis       Pagé                Branch Manager
# 1                 5  Élizabeth     Michel  Level 3 Sales Representative
# 2                 6      Émile   Clermont  Level 1 Sales Representative
# 3                 7    Étienne     Jauvin  Level 2 Sales Representative
# 4                12    Elsbeth  Wiesinger  Level 2 Sales Representative
#
#           WORK_PHONE  EXTENSION                FAX                   EMAIL  \
# 0  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60       DPage@grtd123.com
# 1  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60     EMichel@grtd123.com
# 2  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60   EClermont@grtd123.com
# 3  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60     EJauvin@grtd123.com
# 4  +(49) 40 663 1990     1818.0  +(49) 40 663 4571  EWiesinger@grtd123.com
#
#    DATE_HIRED  SALES_BRANCH_CODE  MANAGER_CODE
# 0  1996-11-03                  6            18
# 1  1995-06-08                  6             4
# 2  1998-04-07                  6             4
# 3  1997-08-16                  6             4
# 4  1997-02-27                 13            14
#
# Table: satisfaction
#    YEAR  SALES_STAFF_CODE  SATISFACTION_TYPE_CODE
# 0  2022                 4                       5
# 1  2022                 5                       4
# 2  2022                 6                       3
# 3  2022                 7                       4
# 4  2022                12                       4
#
# Table: satisfaction_type
#    SATISFACTION_TYPE_CODE SATISFACTION_TYPE_DESCRIPTION
# 0                       1                 Not satisfied
# 1                       2           Less than satisfied
# 2                       3                     Satisfied
# 3                       4                Very Satisfied
# 4                       5           More than satisfied
#
# Table: training
#    YEAR  SALES_STAFF_CODE  COURSE_CODE
# 0  2022                 4            7
# 1  2022                 5            5
# 2  2022                 5            6
# 3  2022                 5            7
# 4  2022                 6            3
#
# Database/CSV: go_crm_train.sqlite
#
# Table: age_group
#    AGE_GROUP_CODE  UPPER_AGE  LOWER_AGE
# 0               1         20          0
# 1               2         30         21
# 2               3         40         31
# 3               4         50         41
# 4               5         60         51
#
# Table: country
#    COUNTRY_CODE     COUNTRY_EN FLAG_IMAGE  SALES_TERRITORY_CODE
# 0             1         France        F01                     6
# 1             2        Germany        F02                     6
# 2             3  United States        F03                     1
# 3             4         Canada        F04                     1
# 4             5        Austria        F05                     7
#
# Table: retailer
#    RETAILER_CODE  RETAILER_CODEMR        COMPANY_NAME  RETAILER_TYPE_CODE
# 0              1              NaN           ActiForme                   5
# 1             15            234.0          SportsClub                   1
# 2             23            229.0            Anapurna                   3
# 3             32            230.0   Cordages Discount                   4
# 4             33            228.0  Altitudes extrêmes                   6
#
# Table: retailer_contact
#    RETAILER_CONTACT_CODE  RETAILER_SITE_CODE FIRST_NAME LAST_NAME  \
# 0                      4                  19     Gilles    Rapier
# 1                      5                  23     Walter     Baker
# 2                      6                   4      Marie  Turcotte
# 3                      7                   2       Mark     Myers
# 4                      9                  10       Jack  Marshall
#
#        JOB_POSITION_EN  EXTENSION               FAX                    E_MAIL  \
# 0         Site Manager        NaN  1 (613) 740-6701           GRapier@f76.net
# 1         Site Manager        NaN  1 (514) 743-7985     WBaker@maxsnetinc.com
# 2  Assistant Purchaser      635.0  1 (514) 747-2582   MTurcotte@cybserv19.com
# 3  Assistant Purchaser        NaN  1 (514) 741-2277  MMyers@rocksteadyitl.com
# 4         Site Manager        NaN  1 (604) 682-4523     JMarshall@vipce2k.com
#
#   GENDER
# 0      M
# 1      M
# 2      F
# 3      M
# 4      M
#
# Table: retailer_headquarters
#    RETAILER_CODEMR          RETAILER_NAME                 ADDRESS1 ADDRESS2  \
# 0                1            Rock Steady          45, rue Atwater     None
# 1                2           Ultra Sports           2425, rue Peel     None
# 2                3       Mountain Madness      56 North Way Street     None
# 3                4  VIP Department Stores  Suite 125, 129th Street     None
# 4                5      Falcon Outfitters     9755 Riverside Drive     None
#
#          CITY            REGION POSTAL_ZONE  COUNTRY_CODE             PHONE  \
# 0    Montréal            Québec     H2T 9K8             4  1 (514) 747-4481
# 1    Montréal            Québec     H4G 3T4             4  1 (514) 746-1273
# 2  Whitehorse             Yukon     Y2K 6R0             4  1 (867) 667-6953
# 3   Vancouver  British Columbia     V1E 4R6             4  1 (604) 685-1544
# 4      Ottawa           Ontario     K1G 4Z0             4  1 (613) 741-5538
#
#                 FAX  SEGMENT_CODE
# 0  1 (514) 741-2277             2
# 1  1 (514) 747-2582            11
# 2  1 (867) 670-7293             7
# 3  1 (604) 682-3059             4
# 4  1 (613) 740-6701             1
#
# Table: retailer_segment
#    SEGMENT_CODE LANGUAGE                  SEGMENT_NAME  \
# 0             1       EN     Outdoors Shop - Exclusive
# 1             2       EN                 Outdoors Shop
# 2             3       EN                     Golf Shop
# 3             4       EN  Department Store - Exclusive
# 4             5       EN              Department Store
#
#                                  SEGMENT_DESCRIPTION
# 0  Primarily offers camping supplies, hiking equi...
# 1  Primarily offers camping supplies, hiking equi...
# 2   Primarily offers golf equipment and accessories.
# 3  Offers a wide range of goods.  Concentrates on...
# 4                      Offers a wide range of goods.
#
# Table: retailer_site
#    RETAILER_SITE_CODE  RETAILER_CODE            ADDRESS1 ADDRESS2  \
# 0                   1             89  1117 Franklin Blvd     None
# 1                   2             89     45, rue Atwater     None
# 2                   3             89    328 Hodgson Road     None
# 3                   4             90      2425, rue Peel     None
# 4                   5             90       34 8th Avenue     None
#
#           CITY         REGION POSTAL_ZONE  COUNTRY_CODE  ACTIVE_INDICATOR
# 0     Winnipeg       Manitoba     R2C 0M5             4                 1
# 1     Montréal         Québec     H2T 9K8             4                 1
# 2  Fredericton  New Brunswick     E3B 2H2             4                 1
# 3     Montréal         Québec     H4G 3T4             4                 1
# 4      Sudbury        Ontario     M5V 1G5             4                 1
#
# Table: retailer_type
#    RETAILER_TYPE_CODE        RETAILER_TYPE_EN
# 0                   1               Golf Shop
# 1                   2        Department Store
# 2                   3        Direct Marketing
# 3                   4         Warehouse Store
# 4                   5  Equipment Rental Store
#
# Table: sales_demographic
#    DEMOGRAPHIC_CODE  RETAILER_CODEMR  AGE_GROUP_CODE  SALES_PERCENT
# 0                 1                1               1             52
# 1                 2                1               2             24
# 2                 3                1               3             12
# 3                 4                1               4              8
# 4                 5                1               5              3
#
# Table: sales_territory
#    SALES_TERRITORY_CODE TERRITORY_NAME_EN
# 0                     1          Americas
# 1                     4      Asia Pacific
# 2                     5   Northern Europe
# 3                     6    Central Europe
# 4                     7   Southern Europe
#
# Database/CSV: inventory_levels_train.csv
#
# Table: inventory_levels
#    INVENTORY_YEAR  INVENTORY_MONTH  PRODUCT_NUMBER  INVENTORY_COUNT
# 0            2023                4              48             1932
# 1            2023                4              49             1400
# 2            2023                4              50            21705
# 3            2023                4              51             9710
# 4            2023                4              52             5616
#
# Database/CSV: product_forecast_train.csv
#
# Table: product_forecast
#    PRODUCT_NUMBER  YEAR  MONTH  EXPECTED_VOLUME
# 0              45  2023     12               90
# 1              46  2023     12               84
# 2              47  2023     12              468
# 3              48  2023     12               91
# 4              49  2023     12               35

# %% [markdown]
# <h2> merge sales_staff en sales_branch
# <h3> dit was volledig overbodig aangezien de tabellen uniek waren,

# %%
# Haal de sales_branch tabellen uit de twee databases
sales_branch_sales = all_dfs['go_sales_train2.sqlite']['sales_branch']
sales_branch_staff = all_dfs['go_staff_train.sqlite']['sales_branch']

# Zet de twee DataFrames onder elkaar (concatenatie)
merged_sales_branch = pd.concat([sales_branch_sales, sales_branch_staff], ignore_index=True)
# Verwijder eventueel duplicaten op basis van de primaire sleutel (bijv. SALES_BRANCH_CODE)
merged_sales_branch.drop_duplicates(subset='SALES_BRANCH_CODE', inplace=True)

# Voor sales_staff:

sales_staff_staff = all_dfs['go_staff_train.sqlite']['sales_staff']

print (sales_staff_staff)
# Out:
#      SALES_STAFF_CODE FIRST_NAME  LAST_NAME                   POSITION_EN  \
# 0                   4      Denis       Pagé                Branch Manager
# 1                   5  Élizabeth     Michel  Level 3 Sales Representative
# 2                   6      Émile   Clermont  Level 1 Sales Representative
# 3                   7    Étienne     Jauvin  Level 2 Sales Representative
# 4                  12    Elsbeth  Wiesinger  Level 2 Sales Representative
# ..                ...        ...        ...                           ...
# 97                120      Giele   Laermans  Level 1 Sales Representative
# 98                121   François    De Crée  Level 1 Sales Representative
# 99                122     Yvette    Lattrez  Level 3 Sales Representative
# 100               123      Willi  Seefelder  Level 2 Sales Representative
# 101               124     Sabine     Grüner  Level 3 Sales Representative
#
#             WORK_PHONE  EXTENSION                FAX                   EMAIL  \
# 0    +33 1 68 94 52 20      325.0  +33 1 68 94 56 60       DPage@grtd123.com
# 1    +33 1 68 94 52 20      336.0  +33 1 68 94 56 60     EMichel@grtd123.com
# 2    +33 1 68 94 52 20      378.0  +33 1 68 94 56 60   EClermont@grtd123.com
# 3    +33 1 68 94 52 20      398.0  +33 1 68 94 56 60     EJauvin@grtd123.com
# 4    +(49) 40 663 1990     1818.0  +(49) 40 663 4571  EWiesinger@grtd123.com
# ..                 ...        ...                ...                     ...
# 97     +32 16 20.73.21     1340.0    +32 16 20.73.32   GLaermans@grtd123.com
# 98     +32 16 20.73.21     1642.0    +32 16 20.73.32     FDecree@grtd123.com
# 99     +32 16 20.73.21     1633.0    +32 16 20.73.32    YLattrez@grtd123.com
# 100  +(43) 13 79 56 32      325.0  +(43) 13 79 56 33  WSeefelder@grtd123.com
# 101  +(43) 13 79 56 32      348.0  +(43) 13 79 56 33     SGruner@grtd123.com
#
#      DATE_HIRED  SALES_BRANCH_CODE  MANAGER_CODE
# 0    1996-11-03                  6            18
# 1    1995-06-08                  6             4
# 2    1998-04-07                  6             4
# 3    1997-08-16                  6             4
# 4    1997-02-27                 13            14
# ..          ...                ...           ...
# 97   1999-11-15                 38           119
# 98   1999-12-01                 38           119
# 99   1999-12-09                 38           119
# 100  1998-10-28                 39            18
# 101  1998-02-18                 39            18
#
# [102 rows x 11 columns]

# %% [markdown]
# <h2> merge country

# %%
# Laad beide country DataFrames
crm_country = all_dfs['go_crm_train.sqlite']['country']
sales_country = all_dfs['go_sales_train2.sqlite']['country']

# Hernoem de kolom in sales_country
sales_country = sales_country.rename(columns={'COUNTRY': 'COUNTRY_EN_SALES'})

# Hernoem de kolom in crm_country (als deze ook COUNTRY_EN heet)
crm_country = crm_country.rename(columns={'COUNTRY_EN': 'COUNTRY_EN_CRM'})

# Merge op COUNTRY_CODE; we combineren de velden zodat we alle attributen hebben
merged_country = pd.merge(sales_country, crm_country, on='COUNTRY_CODE', how='outer')

#merge country_en en country
merged_country['COUNTRY_EN'] = (
    merged_country['COUNTRY_EN_SALES']
    .fillna(merged_country['COUNTRY_EN_CRM'])
)
#verwijder overbodige kolommen
merged_country = merged_country.drop(
    columns=['COUNTRY_EN_SALES', 'COUNTRY_EN_CRM']
)

# Definieer de gewenste kolomvolgorde
gewenste_volgorde = [
    'COUNTRY_CODE',  
    'COUNTRY_EN',    
    'LANGUAGE',      
    'CURRENCY_NAME',
    'FLAG_IMAGE',   
    'SALES_TERRITORY_CODE',
]

# Pas de volgorde toe op de DataFrame
merged_country = merged_country[gewenste_volgorde] 


# Print de aangepaste DataFrame
print(merged_country)
# Out:
#     COUNTRY_CODE      COUNTRY_EN LANGUAGE CURRENCY_NAME FLAG_IMAGE  \
# 0              1          France       EN        francs        F01
# 1              2         Germany       EN         marks        F02
# 2              3   United States       EN       dollars        F03
# 3              4          Canada       EN       dollars        F04
# 4              5         Austria       EN    schillings        F05
# 5              6           Italy       EN          lira        F06
# 6              7     Netherlands       EN      guilders        F07
# 7              8     Switzerland       EN        francs        F08
# 8              9  United Kingdom       EN        pounds        F09
# 9             10          Sweden       EN         krona        F10
# 10            11           Japan       EN           yen        F11
# 11            12          Taiwan       EN    new dollar        F12
# 12            13           Korea       EN           won        F13
# 13            14           China       EN      renminbi        F14
# 14            16       Australia       EN       dollars        F15
# 15            17         Belgium       EN        francs        F16
# 16            18         Denmark       EN        kroner        F17
# 17            19           Spain       EN       pesetas        F18
# 18            20          Mexico       EN         pesos        F19
# 19            21          Brazil       EN         reals        F20
# 20            22         Finland       EN        markka        F21
#
#     SALES_TERRITORY_CODE
# 0                      6
# 1                      6
# 2                      1
# 3                      1
# 4                      7
# 5                      7
# 6                      5
# 7                      6
# 8                      6
# 9                      5
# 10                     4
# 11                     4
# 12                     4
# 13                     4
# 14                     4
# 15                     6
# 16                     5
# 17                     7
# 18                     1
# 19                     1
# 20                     5

# %% [markdown]
# <h3> verwijder country en country uit dictionary, en vervang met merged country
#
# <h4> ook met sales branch en sales_staff

# %%
#verwijder sales_staff uit go sales
if 'sales_staff' in all_dfs['go_sales_train2.sqlite']:
    del all_dfs['go_sales_train2.sqlite']['sales_staff']
    print("gelukt!")

# Verwijder sales_branch uit go_sales
if 'sales_branch' in all_dfs['go_sales_train2.sqlite']:
    del all_dfs['go_sales_train2.sqlite']['sales_branch']
    print("gelukt!")
# Out:
# gelukt!
# gelukt!

# %%
#vervang country in go sales met merged country
all_dfs['go_sales_train2.sqlite']['country'] = merged_country

# Verwijder country uit go_crm_train.sqlite (als je deze niet meer apart wilt behouden)
if 'country' in all_dfs['go_crm_train.sqlite']:
    del all_dfs['go_crm_train.sqlite']['country']
    print("gelukt!")

#verwijder retailer_site uit go_crm_train.sqlite
if 'retailer_site' in all_dfs['go_crm_train.sqlite']:
    del all_dfs['go_crm_train.sqlite']['retailer_site']
    print("gelukt!")
# Out:
# gelukt!
# gelukt!

# %% [markdown]
# <h2> check of alle tabellen aanwezig zijn

# %%
# Loop door elke database in all_dfs
for db_name, tables in all_dfs.items():
    print(f"\nDatabase/CSV: {db_name}")
    # Loop door elke tabel in de database
    for table_name, df in tables.items():
        # Bereken het aantal rijen en kolommen in de tabel
        row_count = len(df)
        col_count = len(df.columns)
        kolomnamen = df.columns.tolist()  # Lijst van kolomnamen

        # Print de informatie
        print(f"Tabel: {table_name}")
        print(f"  Aantal rijen: {row_count}")
        print(f"  Aantal kolommen: {col_count}")
        print(f"  Kolomnamen: {kolomnamen}")
# Out:
# Database/CSV: go_sales_train2.sqlite
# Tabel: country
#   Aantal rijen: 21
#   Aantal kolommen: 6
#   Kolomnamen: ['COUNTRY_CODE', 'COUNTRY_EN', 'LANGUAGE', 'CURRENCY_NAME', 'FLAG_IMAGE', 'SALES_TERRITORY_CODE']
# Tabel: order_details
#   Aantal rijen: 37757
#   Aantal kolommen: 7
#   Kolomnamen: ['ORDER_DETAIL_CODE', 'ORDER_NUMBER', 'PRODUCT_NUMBER', 'QUANTITY', 'UNIT_COST', 'UNIT_PRICE', 'UNIT_SALE_PRICE']
# Tabel: order_header
#   Aantal rijen: 4784
#   Aantal kolommen: 8
#   Kolomnamen: ['ORDER_NUMBER', 'RETAILER_NAME', 'RETAILER_SITE_CODE', 'RETAILER_CONTACT_CODE', 'SALES_STAFF_CODE', 'SALES_BRANCH_CODE', 'ORDER_DATE', 'ORDER_METHOD_CODE']
# Tabel: order_method
#   Aantal rijen: 7
#   Aantal kolommen: 2
#   Kolomnamen: ['ORDER_METHOD_CODE', 'ORDER_METHOD_EN']
# Tabel: product
#   Aantal rijen: 115
#   Aantal kolommen: 9
#   Kolomnamen: ['PRODUCT_NUMBER', 'INTRODUCTION_DATE', 'PRODUCT_TYPE_CODE', 'PRODUCTION_COST', 'MARGIN', 'PRODUCT_IMAGE', 'LANGUAGE', 'PRODUCT_NAME', 'DESCRIPTION']
# Tabel: product_line
#   Aantal rijen: 5
#   Aantal kolommen: 2
#   Kolomnamen: ['PRODUCT_LINE_CODE', 'PRODUCT_LINE_EN']
# Tabel: product_type
#   Aantal rijen: 21
#   Aantal kolommen: 3
#   Kolomnamen: ['PRODUCT_TYPE_CODE', 'PRODUCT_LINE_CODE', 'PRODUCT_TYPE_EN']
# Tabel: retailer_site
#   Aantal rijen: 391
#   Aantal kolommen: 9
#   Kolomnamen: ['RETAILER_SITE_CODE', 'RETAILER_CODE', 'ADDRESS1', 'ADDRESS2', 'CITY', 'REGION', 'POSTAL_ZONE', 'COUNTRY_CODE', 'ACTIVE_INDICATOR']
# Tabel: return_reason
#   Aantal rijen: 5
#   Aantal kolommen: 2
#   Kolomnamen: ['RETURN_REASON_CODE', 'RETURN_DESCRIPTION_EN']
# Tabel: returned_item
#   Aantal rijen: 619
#   Aantal kolommen: 5
#   Kolomnamen: ['RETURN_CODE', 'RETURN_DATE', 'ORDER_DETAIL_CODE', 'RETURN_REASON_CODE', 'RETURN_QUANTITY']
#
# Database/CSV: go_staff_train.sqlite
# Tabel: course
#   Aantal rijen: 9
#   Aantal kolommen: 2
#   Kolomnamen: ['COURSE_CODE', 'COURSE_DESCRIPTION']
# Tabel: sales_branch
#   Aantal rijen: 28
#   Aantal kolommen: 7
#   Kolomnamen: ['SALES_BRANCH_CODE', 'ADDRESS1', 'ADDRESS2', 'CITY', 'REGION', 'POSTAL_ZONE', 'COUNTRY_CODE']
# Tabel: sales_staff
#   Aantal rijen: 102
#   Aantal kolommen: 11
#   Kolomnamen: ['SALES_STAFF_CODE', 'FIRST_NAME', 'LAST_NAME', 'POSITION_EN', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'DATE_HIRED', 'SALES_BRANCH_CODE', 'MANAGER_CODE']
# Tabel: satisfaction
#   Aantal rijen: 202
#   Aantal kolommen: 3
#   Kolomnamen: ['YEAR', 'SALES_STAFF_CODE', 'SATISFACTION_TYPE_CODE']
# Tabel: satisfaction_type
#   Aantal rijen: 5
#   Aantal kolommen: 2
#   Kolomnamen: ['SATISFACTION_TYPE_CODE', 'SATISFACTION_TYPE_DESCRIPTION']
# Tabel: training
#   Aantal rijen: 319
#   Aantal kolommen: 3
#   Kolomnamen: ['YEAR', 'SALES_STAFF_CODE', 'COURSE_CODE']
#
# Database/CSV: go_crm_train.sqlite
# Tabel: age_group
#   Aantal rijen: 6
#   Aantal kolommen: 3
#   Kolomnamen: ['AGE_GROUP_CODE', 'UPPER_AGE', 'LOWER_AGE']
# Tabel: retailer
#   Aantal rijen: 109
#   Aantal kolommen: 4
#   Kolomnamen: ['RETAILER_CODE', 'RETAILER_CODEMR', 'COMPANY_NAME', 'RETAILER_TYPE_CODE']
# Tabel: retailer_contact
#   Aantal rijen: 391
#   Aantal kolommen: 9
#   Kolomnamen: ['RETAILER_CONTACT_CODE', 'RETAILER_SITE_CODE', 'FIRST_NAME', 'LAST_NAME', 'JOB_POSITION_EN', 'EXTENSION', 'FAX', 'E_MAIL', 'GENDER']
# Tabel: retailer_headquarters
#   Aantal rijen: 414
#   Aantal kolommen: 11
#   Kolomnamen: ['RETAILER_CODEMR', 'RETAILER_NAME', 'ADDRESS1', 'ADDRESS2', 'CITY', 'REGION', 'POSTAL_ZONE', 'COUNTRY_CODE', 'PHONE', 'FAX', 'SEGMENT_CODE']
# Tabel: retailer_segment
#   Aantal rijen: 12
#   Aantal kolommen: 4
#   Kolomnamen: ['SEGMENT_CODE', 'LANGUAGE', 'SEGMENT_NAME', 'SEGMENT_DESCRIPTION']
# Tabel: retailer_type
#   Aantal rijen: 8
#   Aantal kolommen: 2
#   Kolomnamen: ['RETAILER_TYPE_CODE', 'RETAILER_TYPE_EN']
# Tabel: sales_demographic
#   Aantal rijen: 2484
#   Aantal kolommen: 4
#   Kolomnamen: ['DEMOGRAPHIC_CODE', 'RETAILER_CODEMR', 'AGE_GROUP_CODE', 'SALES_PERCENT']
# Tabel: sales_territory
#   Aantal rijen: 5
#   Aantal kolommen: 2
#   Kolomnamen: ['SALES_TERRITORY_CODE', 'TERRITORY_NAME_EN']
#
# Database/CSV: inventory_levels_train.csv
# Tabel: inventory_levels
#   Aantal rijen: 3543
#   Aantal kolommen: 4
#   Kolomnamen: ['INVENTORY_YEAR', 'INVENTORY_MONTH', 'PRODUCT_NUMBER', 'INVENTORY_COUNT']
#
# Database/CSV: product_forecast_train.csv
# Tabel: product_forecast
#   Aantal rijen: 3529
#   Aantal kolommen: 4
#   Kolomnamen: ['PRODUCT_NUMBER', 'YEAR', 'MONTH', 'EXPECTED_VOLUME']

# %% [markdown]
# <h2> sql server db vullen

# %%
import pandas as pd
import pyodbc

def clean_nan_values(all_dfs):
    for db_name, tables in all_dfs.items():
        for table_name, df in tables.items():
            df = df.astype(object).where(pd.notnull(df), None)  # Fix NULLs
            all_dfs[db_name][table_name] = df
    return all_dfs

# Pas toe op je dictionary
all_dfs = clean_nan_values(all_dfs)


def upload_dataframes_to_sql(all_dfs):
    try:
        # Maak verbinding met de database
        with pyodbc.connect(connection_string, autocommit=False) as conn:
            cursor = conn.cursor()

            print("⏳ Uitschakelen van FOREIGN KEY constraints...")
            cursor.execute("EXEC sp_MSforeachtable 'ALTER TABLE ? NOCHECK CONSTRAINT ALL'")
            conn.commit()

            # Loop door elke database/csv in all_dfs
            for db_name, tables in all_dfs.items():
                print(f"\nBezig met uploaden van {db_name}...")
                
                # Loop door elke tabel in de database/csv
                for table_name, df in tables.items():
                    print(f"\nTabel: {table_name}")
                    
                    # Genereer de kolomnamen voor de INSERT-query
                    columns = ', '.join([f'[{col}]' for col in df.columns])
                    placeholders = ', '.join(['?'] * len(df.columns))
                    insert_query = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
                    
                    # Loop door elke rij in de DataFrame
                    for index, row in df.iterrows():
                        try:
                            row_data = tuple(row)
                            cursor.execute(insert_query, row_data)
                            conn.commit()  # Commit na elke rij
                            print(f"  Rij {index + 1} ✅ Upload voltooid")
                        except pyodbc.Error as e:
                            conn.rollback()  # Rollback bij fouten
                            error_msg = str(e).replace('\n', ' ')
                            print(f"  Rij {index + 1} ❌ Fout: {error_msg}")
                            continue
            
            print("\n⏳ Herinschakelen van FOREIGN KEY constraints...")
            cursor.execute("EXEC sp_MSforeachtable 'ALTER TABLE ? CHECK CONSTRAINT ALL'")
            conn.commit()

            print("\n🎉 Upload voltooid voor alle tabellen!")
            cursor.close()
            conn.close()
            
    except pyodbc.Error as e:
        print(f"❌ Databasefout: {str(e)}")

# Roep de functie aan met je all_dfs dictionary
upload_dataframes_to_sql(all_dfs)
# Out:
# ⏳ Uitschakelen van FOREIGN KEY constraints...
#
# Bezig met uploaden van go_sales_train2.sqlite...
#
# Tabel: country
#   Rij 1 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (1). (2627) (SQLExecDirectW)")
#   Rij 2 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (2). (2627) (SQLExecDirectW)")
#   Rij 3 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (3). (2627) (SQLExecDirectW)")
#   Rij 4 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (4). (2627) (SQLExecDirectW)")
#   Rij 5 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (5). (2627) (SQLExecDirectW)")
#   Rij 6 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (6). (2627) (SQLExecDirectW)")
#   Rij 7 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (7). (2627) (SQLExecDirectW)")
#   Rij 8 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (8). (2627) (SQLExecDirectW)")
#   Rij 9 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (9). (2627) (SQLExecDirectW)")
#   Rij 10 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (10). (2627) (SQLExecDirectW)")
#   Rij 11 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (11). (2627) (SQLExecDirectW)")
#   Rij 12 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (12). (2627) (SQLExecDirectW)")
#   Rij 13 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (13). (2627) (SQLExecDirectW)")
#   Rij 14 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (14). (2627) (SQLExecDirectW)")
#   Rij 15 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (16). (2627) (SQLExecDirectW)")
#   Rij 16 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (17). (2627) (SQLExecDirectW)")
#   Rij 17 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (18). (2627) (SQLExecDirectW)")
#   Rij 18 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (19). (2627) (SQLExecDirectW)")
#   Rij 19 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (20). (2627) (SQLExecDirectW)")
#   Rij 20 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (21). (2627) (SQLExecDirectW)")
#   Rij 21 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__country__FC7F59079386D156'. Cannot insert duplicate key in object 'dbo.country'. The duplicate key value is (22). (2627) (SQLExecDirectW)")
#
# Tabel: order_details
#   Rij 1 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47737). (2627) (SQLExecDirectW)")
#   Rij 2 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47738). (2627) (SQLExecDirectW)")
#   Rij 3 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47739). (2627) (SQLExecDirectW)")
#   Rij 4 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47740). (2627) (SQLExecDirectW)")
#   Rij 5 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47741). (2627) (SQLExecDirectW)")
#   Rij 6 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47742). (2627) (SQLExecDirectW)")
#   Rij 7 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47743). (2627) (SQLExecDirectW)")
#   Rij 8 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47744). (2627) (SQLExecDirectW)")
#   Rij 9 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47745). (2627) (SQLExecDirectW)")
#   Rij 10 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47746). (2627) (SQLExecDirectW)")
#   Rij 11 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47747). (2627) (SQLExecDirectW)")
#   Rij 12 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47748). (2627) (SQLExecDirectW)")
#   Rij 13 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47749). (2627) (SQLExecDirectW)")
#   Rij 14 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47750). (2627) (SQLExecDirectW)")
#   Rij 15 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47751). (2627) (SQLExecDirectW)")
#   Rij 16 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47752). (2627) (SQLExecDirectW)")
#   Rij 17 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47753). (2627) (SQLExecDirectW)")
#   Rij 18 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47754). (2627) (SQLExecDirectW)")
#   Rij 19 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47755). (2627) (SQLExecDirectW)")
#   Rij 20 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47756). (2627) (SQLExecDirectW)")
#   Rij 21 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47757). (2627) (SQLExecDirectW)")
#   Rij 22 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47758). (2627) (SQLExecDirectW)")
#   Rij 23 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47759). (2627) (SQLExecDirectW)")
#   Rij 24 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47760). (2627) (SQLExecDirectW)")
#   Rij 25 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47761). (2627) (SQLExecDirectW)")
#   Rij 26 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47762). (2627) (SQLExecDirectW)")
#   Rij 27 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47763). (2627) (SQLExecDirectW)")
#   Rij 28 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47764). (2627) (SQLExecDirectW)")
#   Rij 29 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47765). (2627) (SQLExecDirectW)")
#   Rij 30 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47766). (2627) (SQLExecDirectW)")
#   Rij 31 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47767). (2627) (SQLExecDirectW)")
#   Rij 32 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47768). (2627) (SQLExecDirectW)")
#   Rij 33 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47769). (2627) (SQLExecDirectW)")
#   Rij 34 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47770). (2627) (SQLExecDirectW)")
#   Rij 35 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47771). (2627) (SQLExecDirectW)")
#   Rij 36 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47772). (2627) (SQLExecDirectW)")
#   Rij 37 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47773). (2627) (SQLExecDirectW)")
#   Rij 38 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47774). (2627) (SQLExecDirectW)")
#   Rij 39 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47775). (2627) (SQLExecDirectW)")
#   Rij 40 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47776). (2627) (SQLExecDirectW)")
#   Rij 41 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47777). (2627) (SQLExecDirectW)")
#   Rij 42 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47778). (2627) (SQLExecDirectW)")
#   Rij 43 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47779). (2627) (SQLExecDirectW)")
#   Rij 44 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47780). (2627) (SQLExecDirectW)")
#   Rij 45 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47781). (2627) (SQLExecDirectW)")
#   Rij 46 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47782). (2627) (SQLExecDirectW)")
#   Rij 47 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47783). (2627) (SQLExecDirectW)")
#   Rij 48 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47784). (2627) (SQLExecDirectW)")
#   Rij 49 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47785). (2627) (SQLExecDirectW)")
#   Rij 50 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47786). (2627) (SQLExecDirectW)")
#   Rij 51 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47787). (2627) (SQLExecDirectW)")
#   Rij 52 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47788). (2627) (SQLExecDirectW)")
#   Rij 53 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47789). (2627) (SQLExecDirectW)")
#   Rij 54 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47790). (2627) (SQLExecDirectW)")
#   Rij 55 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47791). (2627) (SQLExecDirectW)")
#   Rij 56 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47792). (2627) (SQLExecDirectW)")
#   Rij 57 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47793). (2627) (SQLExecDirectW)")
#   Rij 58 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47794). (2627) (SQLExecDirectW)")
#   Rij 59 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47795). (2627) (SQLExecDirectW)")
#   Rij 60 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47796). (2627) (SQLExecDirectW)")
#   Rij 61 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47797). (2627) (SQLExecDirectW)")
#   Rij 62 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47798). (2627) (SQLExecDirectW)")
#   Rij 63 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47799). (2627) (SQLExecDirectW)")
#   Rij 64 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47800). (2627) (SQLExecDirectW)")
#   Rij 65 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47801). (2627) (SQLExecDirectW)")
#   Rij 66 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47802). (2627) (SQLExecDirectW)")
#   Rij 67 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47803). (2627) (SQLExecDirectW)")
#   Rij 68 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47804). (2627) (SQLExecDirectW)")
#   Rij 69 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47805). (2627) (SQLExecDirectW)")
#   Rij 70 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47806). (2627) (SQLExecDirectW)")
#   Rij 71 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47807). (2627) (SQLExecDirectW)")
#   Rij 72 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47808). (2627) (SQLExecDirectW)")
#   Rij 73 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47809). (2627) (SQLExecDirectW)")
#   Rij 74 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47810). (2627) (SQLExecDirectW)")
#   Rij 75 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47811). (2627) (SQLExecDirectW)")
#   Rij 76 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47812). (2627) (SQLExecDirectW)")
#   Rij 77 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47813). (2627) (SQLExecDirectW)")
#   Rij 78 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47814). (2627) (SQLExecDirectW)")
#   Rij 79 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47815). (2627) (SQLExecDirectW)")
#   Rij 80 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47816). (2627) (SQLExecDirectW)")
#   Rij 81 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47817). (2627) (SQLExecDirectW)")
#   Rij 82 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47818). (2627) (SQLExecDirectW)")
#   Rij 83 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47819). (2627) (SQLExecDirectW)")
#   Rij 84 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47820). (2627) (SQLExecDirectW)")
#   Rij 85 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47821). (2627) (SQLExecDirectW)")
#   Rij 86 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47822). (2627) (SQLExecDirectW)")
#   Rij 87 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47823). (2627) (SQLExecDirectW)")
#   Rij 88 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47824). (2627) (SQLExecDirectW)")
#   Rij 89 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47825). (2627) (SQLExecDirectW)")
#   Rij 90 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47826). (2627) (SQLExecDirectW)")
#   Rij 91 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47827). (2627) (SQLExecDirectW)")
#   Rij 92 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47828). (2627) (SQLExecDirectW)")
#   Rij 93 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47829). (2627) (SQLExecDirectW)")
#   Rij 94 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47830). (2627) (SQLExecDirectW)")
#   Rij 95 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47831). (2627) (SQLExecDirectW)")
#   Rij 96 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47832). (2627) (SQLExecDirectW)")
#   Rij 97 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47833). (2627) (SQLExecDirectW)")
#   Rij 98 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47834). (2627) (SQLExecDirectW)")
#   Rij 99 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47835). (2627) (SQLExecDirectW)")
#   Rij 100 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47836). (2627) (SQLExecDirectW)")
#   Rij 101 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47837). (2627) (SQLExecDirectW)")
#   Rij 102 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47838). (2627) (SQLExecDirectW)")
#   Rij 103 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47839). (2627) (SQLExecDirectW)")
#   Rij 104 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47840). (2627) (SQLExecDirectW)")
#   Rij 105 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47841). (2627) (SQLExecDirectW)")
#   Rij 106 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47842). (2627) (SQLExecDirectW)")
#   Rij 107 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47843). (2627) (SQLExecDirectW)")
#   Rij 108 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47844). (2627) (SQLExecDirectW)")
#   Rij 109 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47845). (2627) (SQLExecDirectW)")
#   Rij 110 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47846). (2627) (SQLExecDirectW)")
#   Rij 111 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47847). (2627) (SQLExecDirectW)")
#   Rij 112 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47848). (2627) (SQLExecDirectW)")
#   Rij 113 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47849). (2627) (SQLExecDirectW)")
#   Rij 114 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47850). (2627) (SQLExecDirectW)")
#   Rij 115 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47851). (2627) (SQLExecDirectW)")
#   Rij 116 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47852). (2627) (SQLExecDirectW)")
#   Rij 117 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47853). (2627) (SQLExecDirectW)")
#   Rij 118 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47854). (2627) (SQLExecDirectW)")
#   Rij 119 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47855). (2627) (SQLExecDirectW)")
#   Rij 120 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47856). (2627) (SQLExecDirectW)")
#   Rij 121 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47857). (2627) (SQLExecDirectW)")
#   Rij 122 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47858). (2627) (SQLExecDirectW)")
#   Rij 123 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47859). (2627) (SQLExecDirectW)")
#   Rij 124 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47860). (2627) (SQLExecDirectW)")
#   Rij 125 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47861). (2627) (SQLExecDirectW)")
#   Rij 126 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47862). (2627) (SQLExecDirectW)")
#   Rij 127 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47863). (2627) (SQLExecDirectW)")
#   Rij 128 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47864). (2627) (SQLExecDirectW)")
#   Rij 129 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47865). (2627) (SQLExecDirectW)")
#   Rij 130 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47866). (2627) (SQLExecDirectW)")
#   Rij 131 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47867). (2627) (SQLExecDirectW)")
#   Rij 132 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47868). (2627) (SQLExecDirectW)")
#   Rij 133 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47869). (2627) (SQLExecDirectW)")
#   Rij 134 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47870). (2627) (SQLExecDirectW)")
#   Rij 135 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47871). (2627) (SQLExecDirectW)")
#   Rij 136 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47872). (2627) (SQLExecDirectW)")
#   Rij 137 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47873). (2627) (SQLExecDirectW)")
#   Rij 138 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47874). (2627) (SQLExecDirectW)")
#   Rij 139 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47875). (2627) (SQLExecDirectW)")
#   Rij 140 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47876). (2627) (SQLExecDirectW)")
#   Rij 141 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47877). (2627) (SQLExecDirectW)")
#   Rij 142 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47878). (2627) (SQLExecDirectW)")
#   Rij 143 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47879). (2627) (SQLExecDirectW)")
#   Rij 144 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47880). (2627) (SQLExecDirectW)")
#   Rij 145 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47881). (2627) (SQLExecDirectW)")
#   Rij 146 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47882). (2627) (SQLExecDirectW)")
#   Rij 147 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47883). (2627) (SQLExecDirectW)")
#   Rij 148 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47884). (2627) (SQLExecDirectW)")
#   Rij 149 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47885). (2627) (SQLExecDirectW)")
#   Rij 150 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (47886). (2627) (SQLExecDirectW)")
# ...
#   Rij 10938 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76171). (2627) (SQLExecDirectW)")
#   Rij 10939 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76172). (2627) (SQLExecDirectW)")
#   Rij 10940 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76173). (2627) (SQLExecDirectW)")
#   Rij 10941 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76174). (2627) (SQLExecDirectW)")
#   Rij 10942 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76175). (2627) (SQLExecDirectW)")
#   Rij 10943 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76176). (2627) (SQLExecDirectW)")
#   Rij 10944 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76177). (2627) (SQLExecDirectW)")
#   Rij 10945 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76178). (2627) (SQLExecDirectW)")
#   Rij 10946 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76179). (2627) (SQLExecDirectW)")
#   Rij 10947 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76180). (2627) (SQLExecDirectW)")
#   Rij 10948 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76181). (2627) (SQLExecDirectW)")
#   Rij 10949 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76182). (2627) (SQLExecDirectW)")
#   Rij 10950 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76183). (2627) (SQLExecDirectW)")
#   Rij 10951 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76184). (2627) (SQLExecDirectW)")
#   Rij 10952 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76185). (2627) (SQLExecDirectW)")
#   Rij 10953 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76186). (2627) (SQLExecDirectW)")
#   Rij 10954 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76187). (2627) (SQLExecDirectW)")
#   Rij 10955 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76188). (2627) (SQLExecDirectW)")
#   Rij 10956 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76189). (2627) (SQLExecDirectW)")
#   Rij 10957 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76190). (2627) (SQLExecDirectW)")
#   Rij 10958 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76191). (2627) (SQLExecDirectW)")
#   Rij 10959 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76192). (2627) (SQLExecDirectW)")
#   Rij 10960 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76193). (2627) (SQLExecDirectW)")
#   Rij 10961 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76194). (2627) (SQLExecDirectW)")
#   Rij 10962 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76195). (2627) (SQLExecDirectW)")
#   Rij 10963 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76196). (2627) (SQLExecDirectW)")
#   Rij 10964 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76197). (2627) (SQLExecDirectW)")
#   Rij 10965 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76198). (2627) (SQLExecDirectW)")
#   Rij 10966 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76199). (2627) (SQLExecDirectW)")
#   Rij 10967 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76200). (2627) (SQLExecDirectW)")
#   Rij 10968 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76201). (2627) (SQLExecDirectW)")
#   Rij 10969 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76202). (2627) (SQLExecDirectW)")
#   Rij 10970 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76203). (2627) (SQLExecDirectW)")
#   Rij 10971 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76204). (2627) (SQLExecDirectW)")
#   Rij 10972 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76205). (2627) (SQLExecDirectW)")
#   Rij 10973 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76206). (2627) (SQLExecDirectW)")
#   Rij 10974 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76207). (2627) (SQLExecDirectW)")
#   Rij 10975 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76208). (2627) (SQLExecDirectW)")
#   Rij 10976 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76209). (2627) (SQLExecDirectW)")
#   Rij 10977 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76210). (2627) (SQLExecDirectW)")
#   Rij 10978 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76211). (2627) (SQLExecDirectW)")
#   Rij 10979 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76212). (2627) (SQLExecDirectW)")
#   Rij 10980 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76213). (2627) (SQLExecDirectW)")
#   Rij 10981 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76214). (2627) (SQLExecDirectW)")
#   Rij 10982 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76215). (2627) (SQLExecDirectW)")
#   Rij 10983 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76216). (2627) (SQLExecDirectW)")
#   Rij 10984 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76217). (2627) (SQLExecDirectW)")
#   Rij 10985 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76218). (2627) (SQLExecDirectW)")
#   Rij 10986 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76219). (2627) (SQLExecDirectW)")
#   Rij 10987 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76220). (2627) (SQLExecDirectW)")
#   Rij 10988 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76221). (2627) (SQLExecDirectW)")
#   Rij 10989 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76222). (2627) (SQLExecDirectW)")
#   Rij 10990 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76223). (2627) (SQLExecDirectW)")
#   Rij 10991 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76224). (2627) (SQLExecDirectW)")
#   Rij 10992 ❌ Fout: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__order_de__4F3D76061DFF6E30'. Cannot insert duplicate key in object 'dbo.order_details'. The duplicate key value is (76225). (2627) (SQLExecDirectW)")
# ❌ Databasefout: ('08S01', '[08S01] [Microsoft][ODBC Driver 17 for SQL Server]Communication link failure (-2147467259) (SQLEndTran(SQL_ROLLBACK))')
